# %% [markdown]
# # **Manejo de variables**
# ## **Calcular el área de un rectángulo**

# %%
largo = 10
ancho = 5
area = largo * ancho # Area de un rectángulo
print("El área del rectángulo es: ", area)
# Out:
# El área del rectángulo es:  50
