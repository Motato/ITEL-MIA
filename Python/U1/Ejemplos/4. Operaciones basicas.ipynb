# %% [markdown]
# # **Manejo del tipo de datos numéricos en Python**
# ## **Sumatoria**

# %%
12 + 67
# Out:
# 79

# %% [markdown]
# ## **Resta**

# %%
89 - 4
# Out:
# 85

# %% [markdown]
# ## **Multiplicación**

# %%
9 * 7
# Out:
# 63

# %% [markdown]
# ## **División**

# %%
35 / 5
# Out:
# 7.0

# %% [markdown]
# ## **Residuo de la división**

# %%
40 % 5
# Out:
# 0

# %%
40 % 6
# Out:
# 4

# %% [markdown]
# ## **División entera**

# %%
40 // 7
# Out:
# 5

# %% [markdown]
# ## **Cuadrado de un numero o potencia**

# %%
5 ** 2  # Elevar al cuadrado un numero
# Out:
# 25

# %%
5 ** 9  # Se eleva el 5 a la potencia de 9
# Out:
# 1953125

# %% [markdown]
# ## **Operaciones respetando el nivel de precedencia de operadores**

# %%
3 - 2 + 4 * 10  # El orden de precedencia es primero multiplicación y luego suma
# Out:
# 41
